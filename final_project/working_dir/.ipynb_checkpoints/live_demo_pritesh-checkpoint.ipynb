# %% [markdown]
# First, let's load the JSON file which describes the human pose task.  This is in COCO format, it is the category descriptor pulled from the annotations file.  We modify the COCO category slightly, to add a neck keypoint.  We will use this task description JSON to create a topology tensor, which is an intermediate data structure that describes the part linkages, as well as which channels in the part affinity field each linkage corresponds to.

# %%
import json
import trt_pose.coco

with open('/trt_pose/tasks/human_pose/human_pose.json', 'r') as f:
    human_pose = json.load(f)

topology = trt_pose.coco.coco_category_to_topology(human_pose)

# %% [markdown]
# Next, we'll load our model.  Each model takes at least two parameters, *cmap_channels* and *paf_channels* corresponding to the number of heatmap channels
# and part affinity field channels.  The number of part affinity field channels is 2x the number of links, because each link has a channel corresponding to the
# x and y direction of the vector field for each link.

# %%
import trt_pose.models

num_parts = len(human_pose['keypoints'])
num_links = len(human_pose['skeleton'])

model = trt_pose.models.resnet18_baseline_att(num_parts, 2 * num_links).cuda().eval()

# %% [markdown]
# Next, let's load the model weights.  You will need to download these according to the table in the README.

# %%
import torch

MODEL_WEIGHTS = '/trt_pose/tasks/human_pose/resnet18_baseline_att_224x224_A_epoch_249.pth'

model.load_state_dict(torch.load(MODEL_WEIGHTS))
# Out:
# <All keys matched successfully>

# %% [markdown]
# In order to optimize with TensorRT using the python library *torch2trt* we'll also need to create some example data.  The dimensions
# of this data should match the dimensions that the network was trained with.  Since we're using the resnet18 variant that was trained on
# an input resolution of 224x224, we set the width and height to these dimensions.

# %%
WIDTH = 224
HEIGHT = 224

data = torch.zeros((1, 3, HEIGHT, WIDTH)).cuda()

# %% [markdown]
# Next, we'll use [torch2trt](https://github.com/NVIDIA-AI-IOT/torch2trt) to optimize the model.  We'll enable fp16_mode to allow optimizations to use reduced half precision.

# %%
import torch2trt

model_trt = torch2trt.torch2trt(model, [data], fp16_mode=True, max_workspace_size=1<<25)

# %% [markdown]
# The optimized model may be saved so that we do not need to perform optimization again, we can just load the model.  Please note that TensorRT has device specific optimizations, so you can only use an optimized model on similar platforms.

# %%
OPTIMIZED_MODEL = '/trt_pose/tasks/human_pose/resnet18_baseline_att_224x224_A_epoch_249_trt.pth'

torch.save(model_trt.state_dict(), OPTIMIZED_MODEL)

# %% [markdown]
# We could then load the saved model using *torch2trt* as follows.

# %%
from torch2trt import TRTModule

model_trt = TRTModule()
model_trt.load_state_dict(torch.load(OPTIMIZED_MODEL))
# Out:
# <All keys matched successfully>

# %% [markdown]
# We can benchmark the model in FPS with the following code

# %%
import time

t0 = time.time()
torch.cuda.current_stream().synchronize()
for i in range(50):
    y = model_trt(data)
torch.cuda.current_stream().synchronize()
t1 = time.time()

print(50.0 / (t1 - t0))
# Out:
# 33.79238445437392

# %% [markdown]
# Next, let's define a function that will preprocess the image, which is originally in BGR8 / HWC format.

# %%
import cv2
import torchvision.transforms as transforms
import PIL.Image

mean = torch.Tensor([0.485, 0.456, 0.406]).cuda()
std = torch.Tensor([0.229, 0.224, 0.225]).cuda()
device = torch.device('cuda')

def preprocess(image):
    global device
    device = torch.device('cuda')
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = PIL.Image.fromarray(image)
    image = transforms.functional.to_tensor(image).to(device)
    image.sub_(mean[:, None, None]).div_(std[:, None, None])
    return image[None, ...]

# %% [markdown]
# Next, we'll define two callable classes that will be used to parse the objects from the neural network, as well as draw the parsed objects on an image.

# %%
from trt_pose.draw_objects import DrawObjects
from trt_pose.parse_objects import ParseObjects

parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)

# %% [markdown]
# Assuming you're using NVIDIA Jetson, you can use the [jetcam](https://github.com/NVIDIA-AI-IOT/jetcam) package to create an easy to use camera that will produce images in BGR8/HWC format.
#
# If you're not on Jetson, you may need to adapt the code below.

# %%
# !v4l2-ctl -d /dev/video1 --list-formats-ext
# Out:
# ioctl: VIDIOC_ENUM_FMT
# 	Index       : 0
# 	Type        : Video Capture
# 	Pixel Format: 'MJPG' (compressed)
# 	Name        : Motion-JPEG
# 		Size: Discrete 160x120
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 176x144
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 320x240
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 352x288
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 640x480
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 800x600
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 960x720
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
#
# 	Index       : 1
# 	Type        : Video Capture
# 	Pixel Format: 'YUYV'
# 	Name        : YUYV 4:2:2
# 		Size: Discrete 160x120
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 176x144
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 320x240
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 352x288
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 640x480
# 			Interval: Discrete 0.033s (30.000 fps)
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 800x600
# 			Interval: Discrete 0.040s (25.000 fps)
# 			Interval: Discrete 0.050s (20.000 fps)
# 			Interval: Discrete 0.067s (15.000 fps)
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 960x720
# 			Interval: Discrete 0.100s (10.000 fps)
# 			Interval: Discrete 0.200s (5.000 fps)
# 		Size: Discrete 1600x1200
# 			Interval: Discrete 0.200s (5.000 fps)

# %%
from jetcam.usb_camera import USBCamera
from jetcam.csi_camera import CSICamera
#from jetcam.camera import Camera
from jetcam.utils import bgr8_to_jpeg

camera = USBCamera(width=WIDTH, height=HEIGHT, capture_fps=30, capture_device=1)
#camera = CSICamera(width=WIDTH, height=HEIGHT, capture_fps=30)

camera.running = True

# %% [markdown]
# Next, we'll create a widget which will be used to display the camera feed with visualizations.

# %%
import ipywidgets
from IPython.display import display

image_w = ipywidgets.Image(format='jpeg')

display(image_w)
# Out:
# Image(value=b'', format='jpeg')

# %% [markdown]
# Finally, we'll define the main execution loop.  This will perform the following steps
#
# 1.  Preprocess the camera image
# 2.  Execute the neural network
# 3.  Parse the objects from the neural network output
# 4.  Draw the objects onto the camera image
# 5.  Convert the image to JPEG format and stream to the display widget

# %%
kp_map = ["nose", "leftEye", "rightEye", "leftEar", "rightEar", "leftShoulder", "rightShoulder", 
          "leftElbow", "rightElbow", "leftWrist", "rightWrist", "leftHip","rightHip", 
          "leftKnee", "rightKnee", "leftAnkle", "rightAnkle", "1?", "2?"]

'''
hnum: 0 based human index
kpoint : index + keypoints (float type range : 0.0 ~ 1.0 ==> later multiply by image width, height)
'''
def get_keypoint(humans, hnum, peaks):
    #check invalid human index
    kpoint = []
    human = humans[0][hnum]
    C = human.shape[0]
    for j in range(C):
        k = int(human[j])
        print('index:%s :'%(kp_map[j]))
        if k >= 0:
            peak = peaks[0][j][k]   # peak[1]:width, peak[0]:height
            peak = (j, float(peak[0]), float(peak[1]))
            kpoint.append(peak)
            print('[%5.3f, %5.3f]'%(peak[1], peak[2]) )
            print('[%d,%d]'%(peak[1]*224, peak[2]*224) )  
            
        else:    
            peak = (j, None, None)
            kpoint.append(peak)
            print('None')
    return kpoint

# %%
key_point_data = []

# %%
def execute(change):
    image = change['new']
    data = preprocess(image)
    cmap, paf = model_trt(data)
    cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
    counts, objects, peaks = parse_objects(cmap, paf)#, cmap_threshold=0.15, link_threshold=0.15)
    print(cmap.size(), paf.size())
    for i in range(counts[0]):
        print("Human index:%d"%( i ))
        key_point_data.append(get_keypoint(objects, i, peaks))
    draw_objects(image, counts, objects, peaks)
    image_w.value = bgr8_to_jpeg(image[:, ::-1, :])

# %% [markdown]
# If we call the cell below it will execute the function once on the current camera frame.

# %%
execute({'new': camera.value})
# Out:
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.395, 0.443]
# [88,99]
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.396, 0.577]
# [88,129]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.539, 0.613]
# [120,137]
# index:rightElbow :
# None
# index:leftWrist :
# [0.693, 0.609]
# [155,136]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.372, 0.511]
# [83,114]
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.552, 0.442]
# [123,98]
# index:leftWrist :
# None
# index:rightWrist :
# [0.690, 0.436]
# [154,97]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import cv2

def execute2(img):
    data = preprocess(img)
    cmap, paf = model_trt(data)
    cmap, paf = cmap.detach().cpu(), paf.detach().cpu()
    counts, objects, peaks = parse_objects(cmap, paf)#, cmap_threshold=0.15, link_threshold=0.15)
    for i in range(counts[0]):
        print("Human index:%d "%( i ))
        get_keypoint(objects, i, peaks)
    print("Human count:%d len:%d "%(counts[0], len(counts)))
    draw_objects(img, counts, objects, peaks)
    cv2.imshow('key',img)
    cv2.imwrite('/tmp/key.png',img)
    plt.imshow(img)
    plt.show()
    
src = cv2.imread("/image1.png", cv2.IMREAD_COLOR)
img = cv2.resize(src, dsize=(224, 224), interpolation=cv2.INTER_AREA)
parse_objects = ParseObjects(topology)
draw_objects = DrawObjects(topology)
execute2(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-392810be112c> in <module>
#      19
#      20 src = cv2.imread("/image1.png", cv2.IMREAD_COLOR)
# ---> 21 img = cv2.resize(src, dsize=(224, 224), interpolation=cv2.INTER_AREA)
#      22 parse_objects = ParseObjects(topology)
#      23 draw_objects = DrawObjects(topology)
#
# error: /build/opencv-XDqSFW/opencv-3.2.0+dfsg/modules/imgproc/src/imgwarp.cpp:3492: error: (-215) ssize.width > 0 && ssize.height > 0 in function resize

# %% [markdown]
# Call the cell below to attach the execution function to the camera's internal value.  This will cause the execute function to be called whenever a new camera frame is received.

# %%
camera.observe(execute, names='value')
# Out:
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.508]
# [95,113]
# index:leftEye :
# [0.407, 0.518]
# [91,116]
# index:rightEye :
# [0.400, 0.491]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.330, 0.576]
# [73,129]
# index:rightShoulder :
# [0.317, 0.476]
# [70,106]
# index:leftElbow :
# [0.438, 0.608]
# [98,136]
# index:rightElbow :
# [0.525, 0.449]
# [117,100]
# index:leftWrist :
# [0.700, 0.623]
# [156,139]
# index:rightWrist :
# [0.681, 0.428]
# [152,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.317, 0.523]
# [71,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.393, 0.592]
# [88,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.423, 0.507]
# [94,113]
# index:leftEye :
# [0.407, 0.517]
# [91,115]
# index:rightEye :
# [0.399, 0.491]
# [89,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.329, 0.576]
# [73,128]
# index:rightShoulder :
# [0.317, 0.476]
# [70,106]
# index:leftElbow :
# [0.438, 0.608]
# [98,136]
# index:rightElbow :
# [0.525, 0.449]
# [117,100]
# index:leftWrist :
# [0.695, 0.622]
# [155,139]
# index:rightWrist :
# [0.682, 0.428]
# [152,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.316, 0.523]
# [70,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.393, 0.593]
# [88,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.423, 0.507]
# [94,113]
# index:leftEye :
# [0.406, 0.518]
# [90,115]
# index:rightEye :
# [0.400, 0.491]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.330, 0.577]
# [74,129]
# index:rightShoulder :
# [0.318, 0.475]
# [71,106]
# index:leftElbow :
# [0.440, 0.609]
# [98,136]
# index:rightElbow :
# [0.526, 0.448]
# [117,100]
# index:leftWrist :
# [0.701, 0.623]
# [156,139]
# index:rightWrist :
# [0.683, 0.429]
# [153,96]
# index:leftHip :
# [0.490, 0.567]
# [109,126]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.325, 0.523]
# [72,117]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.508]
# [94,113]
# index:leftEye :
# [0.407, 0.518]
# [91,115]
# index:rightEye :
# [0.400, 0.492]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.331, 0.576]
# [74,128]
# index:rightShoulder :
# [0.318, 0.475]
# [71,106]
# index:leftElbow :
# [0.438, 0.609]
# [98,136]
# index:rightElbow :
# [0.527, 0.448]
# [118,100]
# index:leftWrist :
# [0.701, 0.623]
# [156,139]
# index:rightWrist :
# [0.684, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.327, 0.522]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.407, 0.595]
# [91,133]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.423, 0.507]
# [94,113]
# index:leftEye :
# [0.406, 0.518]
# [91,115]
# index:rightEye :
# [0.392, 0.491]
# [87,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.333, 0.576]
# [74,128]
# index:rightShoulder :
# [0.343, 0.470]
# [76,105]
# index:leftElbow :
# [0.439, 0.609]
# [98,136]
# index:rightElbow :
# [0.527, 0.448]
# [117,100]
# index:leftWrist :
# [0.701, 0.623]
# [157,139]
# index:rightWrist :
# [0.684, 0.429]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.520]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.408, 0.595]
# [91,133]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.508]
# [95,113]
# index:leftEye :
# [0.401, 0.517]
# [89,115]
# index:rightEye :
# [0.400, 0.491]
# [89,109]
# index:leftEar :
# [0.338, 0.539]
# [75,120]
# index:rightEar :
# None
# index:leftShoulder :
# [0.333, 0.576]
# [74,129]
# index:rightShoulder :
# [0.344, 0.470]
# [77,105]
# index:leftElbow :
# [0.440, 0.608]
# [98,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.704, 0.623]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.392, 0.461]
# [87,103]
# index:leftElbow :
# None
# index:rightElbow :
# [0.527, 0.448]
# [118,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.684, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.509]
# [95,114]
# index:leftEye :
# [0.401, 0.519]
# [89,116]
# index:rightEye :
# [0.400, 0.493]
# [89,110]
# index:leftEar :
# [0.337, 0.542]
# [75,121]
# index:rightEar :
# None
# index:leftShoulder :
# [0.335, 0.578]
# [74,129]
# index:rightShoulder :
# [0.343, 0.470]
# [76,105]
# index:leftElbow :
# [0.441, 0.609]
# [98,136]
# index:rightElbow :
# [0.529, 0.448]
# [118,100]
# index:leftWrist :
# [0.706, 0.623]
# [158,139]
# index:rightWrist :
# [0.687, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# [0.456, 0.517]
# [102,115]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.523]
# [74,117]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.507]
# [95,113]
# index:leftEye :
# [0.409, 0.517]
# [91,115]
# index:rightEye :
# [0.401, 0.492]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.332, 0.575]
# [74,128]
# index:rightShoulder :
# [0.318, 0.476]
# [71,106]
# index:leftElbow :
# [0.439, 0.608]
# [98,136]
# index:rightElbow :
# [0.525, 0.448]
# [117,100]
# index:leftWrist :
# [0.704, 0.623]
# [157,139]
# index:rightWrist :
# [0.685, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.518]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.382, 0.531]
# [85,118]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.408, 0.593]
# [91,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.433, 0.517]
# [97,115]
# index:leftEye :
# [0.411, 0.522]
# [91,116]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.331, 0.576]
# [74,129]
# index:rightShoulder :
# [0.315, 0.476]
# [70,106]
# index:leftElbow :
# [0.426, 0.605]
# [95,135]
# index:rightElbow :
# [0.429, 0.453]
# [96,101]
# index:leftWrist :
# [0.701, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.316, 0.523]
# [70,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.391, 0.541]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.447]
# [117,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.682, 0.429]
# [152,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.394, 0.591]
# [88,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.432, 0.517]
# [96,115]
# index:leftEye :
# [0.409, 0.523]
# [91,117]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.330, 0.577]
# [73,129]
# index:rightShoulder :
# [0.314, 0.475]
# [70,106]
# index:leftElbow :
# [0.428, 0.604]
# [95,135]
# index:rightElbow :
# [0.429, 0.452]
# [96,101]
# index:leftWrist :
# [0.701, 0.623]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.456, 0.567]
# [102,126]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.315, 0.524]
# [70,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.524, 0.446]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.681, 0.428]
# [152,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.402, 0.588]
# [90,131]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.427, 0.506]
# [95,113]
# index:leftEye :
# [0.403, 0.518]
# [90,116]
# index:rightEye :
# [0.403, 0.489]
# [90,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.330, 0.576]
# [73,129]
# index:rightShoulder :
# [0.315, 0.475]
# [70,106]
# index:leftElbow :
# [0.451, 0.609]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.703, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.492, 0.558]
# [110,125]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.396, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.446]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.684, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.433, 0.507]
# [97,113]
# index:leftEye :
# [0.408, 0.519]
# [91,116]
# index:rightEye :
# [0.405, 0.490]
# [90,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.331, 0.576]
# [74,128]
# index:rightShoulder :
# [0.316, 0.475]
# [70,106]
# index:leftElbow :
# [0.455, 0.609]
# [102,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.705, 0.623]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.491, 0.559]
# [110,125]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.382, 0.534]
# [85,119]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.398, 0.459]
# [89,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.526, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.687, 0.429]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.510]
# [95,114]
# index:leftEye :
# [0.409, 0.522]
# [91,116]
# index:rightEye :
# [0.408, 0.495]
# [91,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.332, 0.578]
# [74,129]
# index:rightShoulder :
# [0.315, 0.474]
# [70,106]
# index:leftElbow :
# [0.490, 0.612]
# [109,137]
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# [0.703, 0.623]
# [157,139]
# index:rightWrist :
# [0.684, 0.428]
# [153,95]
# index:leftHip :
# [0.490, 0.561]
# [109,125]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.326, 0.522]
# [72,116]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.432, 0.519]
# [96,116]
# index:leftEye :
# [0.411, 0.526]
# [92,117]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.578]
# [75,129]
# index:rightShoulder :
# [0.316, 0.474]
# [70,106]
# index:leftElbow :
# [0.429, 0.605]
# [96,135]
# index:rightElbow :
# [0.526, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.685, 0.428]
# [153,95]
# index:leftHip :
# [0.490, 0.560]
# [109,125]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.523]
# [73,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.391, 0.546]
# [87,122]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# [0.509, 0.614]
# [113,137]
# index:rightElbow :
# None
# index:leftWrist :
# [0.704, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.429, 0.450]
# [96,100]
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.431, 0.518]
# [96,116]
# index:leftEye :
# [0.410, 0.526]
# [91,117]
# index:rightEye :
# None
# index:leftEar :
# [0.335, 0.546]
# [75,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.579]
# [75,129]
# index:rightShoulder :
# [0.316, 0.473]
# [70,105]
# index:leftElbow :
# [0.520, 0.614]
# [116,137]
# index:rightElbow :
# [0.431, 0.449]
# [96,100]
# index:leftWrist :
# [0.704, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.489, 0.561]
# [109,125]
# index:rightHip :
# [0.473, 0.499]
# [106,111]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.523]
# [73,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.390, 0.545]
# [87,122]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.685, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.431, 0.517]
# [96,115]
# index:leftEye :
# [0.410, 0.525]
# [91,117]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.580]
# [75,129]
# index:rightShoulder :
# [0.318, 0.474]
# [71,106]
# index:leftElbow :
# [0.521, 0.614]
# [116,137]
# index:rightElbow :
# [0.431, 0.450]
# [96,100]
# index:leftWrist :
# [0.704, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.455, 0.565]
# [101,126]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.523]
# [73,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.390, 0.545]
# [87,122]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.509]
# [95,114]
# index:leftEye :
# [0.410, 0.521]
# [91,116]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.578]
# [75,129]
# index:rightShoulder :
# [0.318, 0.475]
# [71,106]
# index:leftElbow :
# [0.429, 0.605]
# [96,135]
# index:rightElbow :
# [0.430, 0.451]
# [96,100]
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.522]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.390, 0.542]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# [0.522, 0.614]
# [116,137]
# index:rightElbow :
# None
# index:leftWrist :
# [0.706, 0.624]
# [158,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.684, 0.428]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:4
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.405, 0.590]
# [90,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.509]
# [94,114]
# index:leftEye :
# [0.409, 0.522]
# [91,116]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.579]
# [75,129]
# index:rightShoulder :
# [0.318, 0.475]
# [71,106]
# index:leftElbow :
# [0.454, 0.610]
# [101,136]
# index:rightElbow :
# [0.527, 0.444]
# [118,99]
# index:leftWrist :
# [0.707, 0.624]
# [158,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# [0.455, 0.569]
# [101,127]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.522]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.389, 0.543]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.412, 0.593]
# [92,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.511]
# [95,114]
# index:leftEye :
# [0.410, 0.523]
# [91,117]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.334, 0.579]
# [74,129]
# index:rightShoulder :
# [0.317, 0.474]
# [71,106]
# index:leftElbow :
# [0.430, 0.605]
# [96,135]
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# [0.702, 0.624]
# [157,139]
# index:rightWrist :
# [0.686, 0.428]
# [153,95]
# index:leftHip :
# [0.455, 0.569]
# [101,127]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.523]
# [73,117]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.391, 0.543]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.406, 0.592]
# [90,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.510]
# [95,114]
# index:leftEye :
# [0.410, 0.521]
# [91,116]
# index:rightEye :
# [0.408, 0.495]
# [91,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.332, 0.578]
# [74,129]
# index:rightShoulder :
# [0.317, 0.474]
# [70,106]
# index:leftElbow :
# [0.438, 0.607]
# [98,136]
# index:rightElbow :
# [0.431, 0.451]
# [96,101]
# index:leftWrist :
# [0.702, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.457, 0.567]
# [102,127]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.327, 0.522]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.390, 0.542]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.526, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.685, 0.428]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.403, 0.592]
# [90,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.512]
# [95,114]
# index:leftEye :
# [0.408, 0.523]
# [91,117]
# index:rightEye :
# [0.402, 0.497]
# [90,111]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.331, 0.577]
# [74,129]
# index:rightShoulder :
# [0.318, 0.473]
# [71,105]
# index:leftElbow :
# [0.440, 0.607]
# [98,136]
# index:rightElbow :
# [0.528, 0.446]
# [118,99]
# index:leftWrist :
# [0.701, 0.624]
# [156,139]
# index:rightWrist :
# [0.685, 0.429]
# [153,95]
# index:leftHip :
# [0.489, 0.565]
# [109,126]
# index:rightHip :
# [0.474, 0.505]
# [106,113]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.328, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.411, 0.593]
# [91,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.510]
# [95,114]
# index:leftEye :
# [0.409, 0.522]
# [91,116]
# index:rightEye :
# [0.402, 0.495]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.333, 0.577]
# [74,129]
# index:rightShoulder :
# [0.318, 0.474]
# [71,106]
# index:leftElbow :
# [0.440, 0.608]
# [98,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.703, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.457, 0.567]
# [102,126]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.390, 0.542]
# [87,121]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.394, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.428]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.411, 0.593]
# [91,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.511]
# [95,114]
# index:leftEye :
# [0.403, 0.522]
# [90,116]
# index:rightEye :
# [0.402, 0.495]
# [90,110]
# index:leftEar :
# [0.334, 0.546]
# [74,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.335, 0.577]
# [75,129]
# index:rightShoulder :
# [0.319, 0.473]
# [71,106]
# index:leftElbow :
# [0.453, 0.610]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.705, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.489, 0.564]
# [109,126]
# index:rightHip :
# [0.474, 0.505]
# [106,113]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.331, 0.521]
# [74,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.393, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.527, 0.445]
# [118,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.690, 0.428]
# [154,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.510]
# [94,114]
# index:leftEye :
# [0.402, 0.523]
# [90,117]
# index:rightEye :
# [0.400, 0.494]
# [89,110]
# index:leftEar :
# [0.334, 0.548]
# [74,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.579]
# [75,129]
# index:rightShoulder :
# [0.320, 0.473]
# [71,106]
# index:leftElbow :
# [0.456, 0.610]
# [102,136]
# index:rightElbow :
# [0.525, 0.444]
# [117,99]
# index:leftWrist :
# [0.705, 0.624]
# [157,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# [0.491, 0.562]
# [109,125]
# index:rightHip :
# [0.488, 0.498]
# [109,111]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.522]
# [74,116]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.509]
# [95,114]
# index:leftEye :
# [0.402, 0.522]
# [90,116]
# index:rightEye :
# [0.401, 0.494]
# [89,110]
# index:leftEar :
# [0.335, 0.548]
# [75,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.579]
# [75,129]
# index:rightShoulder :
# [0.330, 0.472]
# [73,105]
# index:leftElbow :
# [0.490, 0.613]
# [109,137]
# index:rightElbow :
# [0.525, 0.445]
# [117,99]
# index:leftWrist :
# [0.705, 0.624]
# [157,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# [0.489, 0.563]
# [109,126]
# index:rightHip :
# [0.473, 0.505]
# [106,113]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.522]
# [74,116]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.509]
# [95,113]
# index:leftEye :
# [0.402, 0.522]
# [90,116]
# index:rightEye :
# [0.401, 0.493]
# [89,110]
# index:leftEar :
# [0.335, 0.548]
# [75,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.579]
# [75,129]
# index:rightShoulder :
# [0.321, 0.473]
# [71,105]
# index:leftElbow :
# [0.491, 0.612]
# [110,137]
# index:rightElbow :
# [0.524, 0.445]
# [117,99]
# index:leftWrist :
# [0.705, 0.624]
# [157,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# [0.489, 0.563]
# [109,126]
# index:rightHip :
# [0.473, 0.504]
# [106,112]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.522]
# [74,116]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.508]
# [94,113]
# index:leftEye :
# [0.402, 0.521]
# [90,116]
# index:rightEye :
# [0.400, 0.493]
# [89,110]
# index:leftEar :
# [0.335, 0.546]
# [75,122]
# index:rightEar :
# None
# index:leftShoulder :
# [0.337, 0.578]
# [75,129]
# index:rightShoulder :
# [0.319, 0.474]
# [71,106]
# index:leftElbow :
# [0.490, 0.612]
# [109,137]
# index:rightElbow :
# [0.525, 0.444]
# [117,99]
# index:leftWrist :
# [0.705, 0.623]
# [157,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# [0.489, 0.565]
# [109,126]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.331, 0.521]
# [74,116]
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.423, 0.508]
# [94,113]
# index:leftEye :
# [0.402, 0.520]
# [90,116]
# index:rightEye :
# [0.401, 0.492]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.335, 0.578]
# [74,129]
# index:rightShoulder :
# [0.319, 0.474]
# [71,106]
# index:leftElbow :
# [0.454, 0.609]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.703, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.457, 0.565]
# [102,126]
# index:rightHip :
# [0.458, 0.504]
# [102,112]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.393, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.445]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.414, 0.593]
# [92,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.508]
# [94,113]
# index:leftEye :
# [0.408, 0.520]
# [91,116]
# index:rightEye :
# [0.401, 0.492]
# [89,110]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.576]
# [75,129]
# index:rightShoulder :
# [0.319, 0.474]
# [71,106]
# index:leftElbow :
# [0.453, 0.608]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.706, 0.624]
# [158,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.455, 0.569]
# [102,127]
# index:rightHip :
# [0.457, 0.510]
# [102,114]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.521]
# [73,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.392, 0.460]
# [87,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.446]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.404, 0.589]
# [90,131]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.507]
# [95,113]
# index:leftEye :
# [0.409, 0.518]
# [91,116]
# index:rightEye :
# [0.408, 0.491]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.576]
# [75,128]
# index:rightShoulder :
# [0.344, 0.469]
# [77,105]
# index:leftElbow :
# [0.451, 0.609]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.706, 0.624]
# [158,139]
# index:rightWrist :
# None
# index:leftHip :
# [0.454, 0.570]
# [101,127]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.519]
# [74,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.381, 0.535]
# [85,119]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.393, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.525, 0.446]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.429]
# [153,96]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.405, 0.589]
# [90,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.506]
# [95,113]
# index:leftEye :
# [0.409, 0.518]
# [91,116]
# index:rightEye :
# [0.409, 0.490]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.575]
# [75,128]
# index:rightShoulder :
# [0.345, 0.469]
# [77,105]
# index:leftElbow :
# [0.454, 0.608]
# [101,136]
# index:rightElbow :
# None
# index:leftWrist :
# [0.705, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.519]
# [74,116]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.380, 0.534]
# [85,119]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.393, 0.459]
# [88,102]
# index:leftElbow :
# None
# index:rightElbow :
# [0.526, 0.444]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.690, 0.428]
# [154,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.406, 0.589]
# [90,131]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.508]
# [95,113]
# index:leftEye :
# [0.408, 0.519]
# [91,116]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.338, 0.575]
# [75,128]
# index:rightShoulder :
# [0.343, 0.469]
# [76,105]
# index:leftElbow :
# [0.441, 0.606]
# [98,135]
# index:rightElbow :
# [0.524, 0.444]
# [117,99]
# index:leftWrist :
# [0.704, 0.624]
# [157,139]
# index:rightWrist :
# [0.687, 0.428]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.517]
# [73,115]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# [0.318, 0.474]
# [71,106]
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.413, 0.592]
# [92,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.505]
# [95,113]
# index:leftEye :
# [0.409, 0.517]
# [91,115]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.337, 0.575]
# [75,128]
# index:rightShoulder :
# [0.318, 0.473]
# [71,105]
# index:leftElbow :
# [0.455, 0.609]
# [102,136]
# index:rightElbow :
# [0.431, 0.449]
# [96,100]
# index:leftWrist :
# [0.705, 0.624]
# [158,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.516]
# [73,115]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.444]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.689, 0.428]
# [154,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.414, 0.592]
# [92,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.506]
# [95,113]
# index:leftEye :
# [0.409, 0.519]
# [91,116]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.346, 0.576]
# [77,128]
# index:rightShoulder :
# [0.318, 0.473]
# [71,105]
# index:leftElbow :
# [0.491, 0.612]
# [109,136]
# index:rightElbow :
# [0.431, 0.449]
# [96,100]
# index:leftWrist :
# [0.706, 0.624]
# [158,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.329, 0.516]
# [73,115]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.522, 0.444]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.686, 0.427]
# [153,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# [0.416, 0.592]
# [93,132]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.503]
# [95,112]
# index:leftEye :
# [0.409, 0.516]
# [91,115]
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.345, 0.574]
# [77,128]
# index:rightShoulder :
# [0.318, 0.472]
# [71,105]
# index:leftElbow :
# [0.488, 0.611]
# [109,136]
# index:rightElbow :
# [0.431, 0.449]
# [96,100]
# index:leftWrist :
# [0.703, 0.624]
# [157,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.330, 0.514]
# [73,115]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# [0.380, 0.531]
# [85,118]
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.523, 0.443]
# [117,99]
# index:leftWrist :
# None
# index:rightWrist :
# [0.687, 0.427]
# [153,95]
# index:leftHip :
# None
# ...
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.540, 0.449]
# [120,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.698, 0.428]
# [156,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.432, 0.491]
# [96,110]
# index:leftEye :
# [0.407, 0.496]
# [91,111]
# index:rightEye :
# [0.412, 0.480]
# [92,107]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.336, 0.562]
# [75,125]
# index:rightShoulder :
# [0.347, 0.465]
# [77,104]
# index:leftElbow :
# [0.435, 0.594]
# [97,132]
# index:rightElbow :
# [0.539, 0.448]
# [120,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.699, 0.428]
# [156,95]
# index:leftHip :
# [0.402, 0.576]
# [90,129]
# index:rightHip :
# [0.439, 0.514]
# [98,115]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.331, 0.508]
# [74,113]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.321, 0.478]
# [71,107]
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# [0.561, 0.598]
# [125,133]
# index:rightElbow :
# None
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.432, 0.492]
# [96,110]
# index:leftEye :
# [0.405, 0.496]
# [90,111]
# index:rightEye :
# [0.412, 0.481]
# [92,107]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.343, 0.563]
# [76,126]
# index:rightShoulder :
# [0.348, 0.467]
# [77,104]
# index:leftElbow :
# [0.436, 0.593]
# [97,132]
# index:rightElbow :
# [0.444, 0.452]
# [99,101]
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# [0.402, 0.579]
# [90,129]
# index:rightHip :
# [0.440, 0.521]
# [98,116]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.509]
# [74,113]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.315, 0.479]
# [70,107]
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# [0.560, 0.599]
# [125,134]
# index:rightElbow :
# None
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:3
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.540, 0.449]
# [120,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.698, 0.428]
# [156,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.431, 0.493]
# [96,110]
# index:leftEye :
# [0.404, 0.497]
# [90,111]
# index:rightEye :
# [0.411, 0.483]
# [92,108]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.344, 0.564]
# [77,126]
# index:rightShoulder :
# [0.347, 0.467]
# [77,104]
# index:leftElbow :
# [0.429, 0.591]
# [96,132]
# index:rightElbow :
# [0.457, 0.451]
# [102,101]
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# [0.402, 0.579]
# [90,129]
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.511]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.478]
# [70,106]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.546, 0.600]
# [122,134]
# index:rightElbow :
# None
# index:leftWrist :
# [0.723, 0.622]
# [162,139]
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# None
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# [0.540, 0.449]
# [120,100]
# index:leftWrist :
# None
# index:rightWrist :
# [0.693, 0.428]
# [155,95]
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.423, 0.494]
# [94,110]
# index:leftEye :
# [0.403, 0.498]
# [90,111]
# index:rightEye :
# [0.411, 0.486]
# [91,108]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.345, 0.565]
# [77,126]
# index:rightShoulder :
# [0.347, 0.468]
# [77,104]
# index:leftElbow :
# [0.548, 0.601]
# [122,134]
# index:rightElbow :
# [0.542, 0.449]
# [121,100]
# index:leftWrist :
# [0.725, 0.622]
# [162,139]
# index:rightWrist :
# [0.699, 0.428]
# [156,95]
# index:leftHip :
# [0.403, 0.580]
# [90,129]
# index:rightHip :
# [0.440, 0.521]
# [98,116]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.512]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.479]
# [70,107]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.592]
# [95,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.494]
# [94,110]
# index:leftEye :
# [0.403, 0.498]
# [90,111]
# index:rightEye :
# [0.411, 0.485]
# [92,108]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.345, 0.564]
# [77,126]
# index:rightShoulder :
# [0.348, 0.467]
# [78,104]
# index:leftElbow :
# [0.561, 0.602]
# [125,134]
# index:rightElbow :
# [0.543, 0.448]
# [121,100]
# index:leftWrist :
# [0.726, 0.622]
# [162,139]
# index:rightWrist :
# [0.700, 0.428]
# [156,95]
# index:leftHip :
# [0.402, 0.581]
# [90,130]
# index:rightHip :
# [0.439, 0.522]
# [98,116]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.511]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.315, 0.480]
# [70,107]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.429, 0.593]
# [96,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.496]
# [95,111]
# index:leftEye :
# [0.403, 0.500]
# [90,111]
# index:rightEye :
# [0.411, 0.487]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.346, 0.565]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.549, 0.601]
# [122,134]
# index:rightElbow :
# [0.543, 0.449]
# [121,100]
# index:leftWrist :
# [0.724, 0.622]
# [162,139]
# index:rightWrist :
# [0.700, 0.429]
# [156,96]
# index:leftHip :
# [0.403, 0.583]
# [90,130]
# index:rightHip :
# [0.439, 0.525]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.334, 0.511]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.488]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.429, 0.593]
# [96,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.501]
# [95,112]
# index:leftEye :
# [0.402, 0.501]
# [90,112]
# index:rightEye :
# [0.410, 0.488]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.346, 0.565]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.547, 0.601]
# [122,134]
# index:rightElbow :
# [0.542, 0.449]
# [121,100]
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# [0.700, 0.428]
# [156,95]
# index:leftHip :
# [0.403, 0.583]
# [90,130]
# index:rightHip :
# [0.440, 0.525]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.334, 0.511]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.315, 0.489]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.429, 0.594]
# [96,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.501]
# [94,112]
# index:leftEye :
# [0.402, 0.501]
# [90,112]
# index:rightEye :
# [0.410, 0.489]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.346, 0.566]
# [77,126]
# index:rightShoulder :
# [0.349, 0.469]
# [78,104]
# index:leftElbow :
# [0.562, 0.601]
# [125,134]
# index:rightElbow :
# [0.542, 0.449]
# [121,100]
# index:leftWrist :
# [0.724, 0.621]
# [162,139]
# index:rightWrist :
# [0.700, 0.429]
# [156,96]
# index:leftHip :
# [0.403, 0.583]
# [90,130]
# index:rightHip :
# [0.440, 0.526]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.334, 0.513]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.487]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.594]
# [95,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.496]
# [94,111]
# index:leftEye :
# [0.402, 0.500]
# [90,111]
# index:rightEye :
# [0.410, 0.486]
# [91,108]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.345, 0.564]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.560, 0.601]
# [125,134]
# index:rightElbow :
# [0.542, 0.449]
# [121,100]
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# [0.699, 0.428]
# [156,95]
# index:leftHip :
# [0.403, 0.583]
# [90,130]
# index:rightHip :
# [0.439, 0.527]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.512]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.488]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.594]
# [95,133]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.425, 0.500]
# [95,112]
# index:leftEye :
# [0.402, 0.500]
# [90,112]
# index:rightEye :
# [0.411, 0.487]
# [92,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.345, 0.565]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.561, 0.601]
# [125,134]
# index:rightElbow :
# [0.541, 0.449]
# [121,100]
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# [0.699, 0.428]
# [156,95]
# index:leftHip :
# [0.402, 0.584]
# [90,130]
# index:rightHip :
# [0.439, 0.528]
# [98,118]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.512]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.482]
# [70,107]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.593]
# [95,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.500]
# [94,111]
# index:leftEye :
# [0.402, 0.500]
# [90,112]
# index:rightEye :
# [0.410, 0.487]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.346, 0.565]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.548, 0.601]
# [122,134]
# index:rightElbow :
# [0.543, 0.449]
# [121,100]
# index:leftWrist :
# [0.722, 0.621]
# [161,139]
# index:rightWrist :
# [0.701, 0.428]
# [157,95]
# index:leftHip :
# [0.401, 0.584]
# [89,130]
# index:rightHip :
# [0.438, 0.527]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.512]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.313, 0.489]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.594]
# [95,133]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.426, 0.500]
# [95,112]
# index:leftEye :
# [0.404, 0.500]
# [90,111]
# index:rightEye :
# [0.412, 0.486]
# [92,108]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.347, 0.565]
# [77,126]
# index:rightShoulder :
# [0.349, 0.468]
# [78,104]
# index:leftElbow :
# [0.549, 0.601]
# [122,134]
# index:rightElbow :
# [0.542, 0.449]
# [121,100]
# index:leftWrist :
# [0.721, 0.620]
# [161,138]
# index:rightWrist :
# [0.698, 0.429]
# [156,95]
# index:leftHip :
# [0.401, 0.585]
# [89,131]
# index:rightHip :
# [0.437, 0.529]
# [97,118]
# index:leftKnee :
# [0.408, 0.581]
# [91,130]
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.332, 0.512]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.313, 0.488]
# [70,109]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.428, 0.593]
# [95,132]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# Human index:2
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None

# %% [markdown]
# Call the cell below to unattach the camera frame callbacks.

# %%
camera.unobserve_all()
# Out:
# index:leftShoulder :
# [0.322, 0.480]
# [72,107]
# index:rightShoulder :
# None
# index:leftElbow :
# None
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None
# torch.Size([1, 18, 56, 56]) torch.Size([1, 42, 56, 56])
# Human index:0
# index:nose :
# [0.424, 0.500]
# [95,112]
# index:leftEye :
# [0.403, 0.501]
# [90,112]
# index:rightEye :
# [0.411, 0.487]
# [91,109]
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.347, 0.566]
# [77,126]
# index:rightShoulder :
# [0.348, 0.469]
# [78,104]
# index:leftElbow :
# [0.562, 0.601]
# [125,134]
# index:rightElbow :
# [0.545, 0.449]
# [122,100]
# index:leftWrist :
# [0.724, 0.622]
# [162,139]
# index:rightWrist :
# [0.703, 0.428]
# [157,95]
# index:leftHip :
# [0.402, 0.584]
# [89,130]
# index:rightHip :
# [0.438, 0.527]
# [98,117]
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# [0.333, 0.513]
# [74,114]
# Human index:1
# index:nose :
# None
# index:leftEye :
# None
# index:rightEye :
# None
# index:leftEar :
# None
# index:rightEar :
# None
# index:leftShoulder :
# [0.314, 0.482]
# [70,107]
# index:rightShoulder :
# None
# index:leftElbow :
# [0.427, 0.594]
# [95,133]
# index:rightElbow :
# None
# index:leftWrist :
# None
# index:rightWrist :
# None
# index:leftHip :
# None
# index:rightHip :
# None
# index:leftKnee :
# None
# index:rightKnee :
# None
# index:leftAnkle :
# None
# index:rightAnkle :
# None
# index:1? :
# None

# %%
key_point_data
# Out:
# [[(0, 0.008928571827709675, 0.5423222184181213),
#   (1, None, None),
#   (2, None, None),
#   (3, 0.008928571827709675, 0.5666031241416931),
#   (4, None, None),
#   (5, 0.06321463733911514, 0.5949721336364746),
#   (6, 0.0664222314953804, 0.48520153760910034),
#   (7, 0.008928571827709675, 0.6505074501037598),
#   (8, 0.01953505538403988, 0.4473792612552643),
#   (9, None, None),
#   (10, None, None),
#   (11, 0.3779276907444, 0.5675686597824097),
#   (12, 0.3707892894744873, 0.4825475215911865),
#   (13, 0.6275882124900818, 0.5684719085693359),
#   (14, 0.6204110980033875, 0.49446901679039),
#   (15, 0.8292998671531677, 0.5573303699493408),
#   (16, 0.8276861310005188, 0.48857608437538147),
#   (17, 0.06496793776750565, 0.5398879647254944)],
#  [(0, 0.1533588021993637, 0.5289508104324341),
#   (1, 0.13647006452083588, 0.545482337474823),
#   (2, 0.13551954925060272, 0.5167061686515808),
#   (3, 0.16238856315612793, 0.5676344037055969),
#   (4, 0.1575915664434433, 0.4998515248298645),
#   (5, 0.2653340995311737, 0.5893524885177612),
#   (6, 0.2641530930995941, 0.47289523482322693),
#   (7, 0.16854877769947052, 0.6562495231628418),
#   (8, 0.15284951031208038, 0.4049008786678314),
#   (9, 0.008928571827709675, 0.7016787528991699),
#   (10, 0.008928571827709675, 0.3553811013698578),
#   (11, 0.5751987099647522, 0.5644137859344482),
#   (12, 0.57419353723526, 0.47882670164108276),
#   (13, 0.8119887113571167, 0.5721617937088013),
#   (14, 0.8026311993598938, 0.49333494901657104),
#   (15, 0.991071343421936, 0.5669392943382263),
#   (16, 0.9910715222358704, 0.49418848752975464),
#   (17, 0.2645004391670227, 0.5298343896865845)],
#  [(0, 0.15310709178447723, 0.5368791818618774),
#   (1, 0.13666217029094696, 0.5529552102088928),
#   (2, 0.13502585887908936, 0.5236350893974304),
#   (3, 0.1633846014738083, 0.5740790963172913),
#   (4, 0.15718881785869598, 0.5051308274269104),
#   (5, 0.2625841796398163, 0.5927704572677612),
#   (6, 0.26217538118362427, 0.4781375229358673),
#   (7, 0.17126068472862244, 0.6560239791870117),
#   (8, 0.135410875082016, 0.40282535552978516),
#   (9, 0.008928571827709675, 0.7060803771018982),
#   (10, 0.008928571827709675, 0.35918474197387695),
#   (11, 0.5759745240211487, 0.5679286122322083),
#   (12, 0.5745741724967957, 0.48144224286079407),
#   (13, 0.8111371994018555, 0.5729070901870728),
#   (10, 0.008928571827709675, 0.3551975190639496),
#   (11, 0.5804921984672546, 0.5689757466316223),
#   (12, 0.5793877840042114, 0.482060045003891),
#   (13, 0.8132415413856506, 0.5754665732383728),
#   (14, 0.8069032430648804, 0.49346891045570374),
#   (15, 0.9910714030265808, 0.5680965185165405),
#   (16, 0.9910714030265808, 0.4940687119960785),
#   (17, 0.26611676812171936, 0.5284488797187805)],
#  ...]

# %%
key_point_data_down_dog = key_point_data

# %%
key_point_data_mountain_pose = key_point_data

# %%
import numpy as np 
np.save('mountain_pose_data', np.array(key_point_data_mountain_pose))
# Out:
# array([[[0, 0.16358527541160583, 0.5434093475341797],
#         [1, 0.14571022987365723, 0.559847891330719],
#         [2, 0.1445523351430893, 0.5307434797286987],
#         ...,
#         [15, 0.9844337105751038, 0.5628499984741211],
#         [16, 0.9827998876571655, 0.4996297359466553],
#         [17, 0.3011482059955597, 0.5385745167732239]],
#
#        [[0, None, None],
#         [1, None, None],
#         [2, None, None],
#         ...,
#         [15, None, None],
#         [16, None, None],
#         [17, None, None]],
#
#        [[0, 0.15283262729644775, 0.5336130261421204],
#         [1, 0.1377248466014862, 0.5502042174339294],
#         [2, 0.13597746193408966, 0.5211321115493774],
#         ...,
#         [15, 0.9827622771263123, 0.5633050799369812],
#         [16, 0.9830611944198608, 0.5065416693687439],
#         [17, 0.2690748870372772, 0.5308191180229187]],
#
#        ...,
#
#        [[0, 0.1596592515707016, 0.5286185145378113],
#         [1, 0.1420818418264389, 0.5443055033683777],
#         [2, 0.14024390280246735, 0.5148287415504456],
#         ...,
#         [15, 0.9836483001708984, 0.5627202391624451],
#         [16, 0.9830335974693298, 0.5017254948616028],
#         [17, 0.2698272466659546, 0.5283103585243225]],
#
#        [[0, 0.16013027727603912, 0.5286136865615845],
#         [1, 0.14268997311592102, 0.544184684753418],
#         [2, 0.14076434075832367, 0.5149403810501099],
#         ...,
#         [15, 0.9839924573898315, 0.5620676279067993],
#         [16, 0.9830177426338196, 0.5011258125305176],
#         [17, 0.2702813446521759, 0.5284442901611328]],
#
#        [[0, 0.15933118760585785, 0.5281872153282166],
#         [1, 0.1419333666563034, 0.5438355207443237],
#         [2, 0.13990823924541473, 0.5145689845085144],
#         ...,
#         [15, 0.9830086827278137, 0.5622252821922302],
#         [16, 0.9828502535820007, 0.5011120438575745],
#         [17, 0.27006369829177856, 0.5282759070396423]]], dtype=object)

# %%
np.save('downDog_pose_data', np.array(key_point_data_down_dog))

# %%
# !ls -la
# Out:
# total 3088
# drwxr-xr-x 3 root root    4096 Jul 27 22:50 .
# drwxr-xr-x 6 root root    4096 Jul 27 19:10 ..
# drwxr-xr-x 2 root root    4096 Jul 27 19:13 .ipynb_checkpoints
# -rw-r--r-- 1 root root  245281 Jul 27 22:50 downDog_pose_data.npy
# -rw-r--r-- 1 root root 2561483 Jul 27 22:50 live_demo_pritesh.ipynb
# -rw-r--r-- 1 root root  337261 Jul 27 22:47 mountain_pose_data.npy

# %%
len(key_point_data)
# Out:
# 1518
